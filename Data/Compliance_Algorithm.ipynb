# %% [markdown]
# # This Notebook contains the development of the Compliance_Algorithm #

# %% [markdown]
# ## Imports ##

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import Data_Explo_HELPER as halp
import Compl_Algo_Helper as comp_halp

# %% [markdown]
# #### *Loading Patient Data* ####

# %%
#Return order is breatD, esoData, FFFT
breathD, esoData, FFFT = halp.patientManager(11,"entire")

#Create object holding vent setting
Vent_Setting = halp.Ventilator()

print(f"amt of parts is: {int(len(esoData.columns)/12)}")
# Out:
# NOTE: For patient 5, 16 and 21, missing values have been imputated
# The imputated values are are:
# Patient 5: part 3
# Patient 16: part 4
# Patient 21: part 2
# amt of parts is: 8

# %%
parts = {1 : 7, 
        2 : 7,
        3 : 10,
        4 : 7,
        5 : 3,
        6 : 2,
        7 : 6,
        8 : 7,
        9 : 7,
        10 : 8,
        11 : 9,
        12 : 9,
        13 : 2,
        14 : 2,
        15 : 2,
        16 : 9}

# %% [markdown]
# ### Check quality of data ###

# %% [markdown]
# #### *Filtering Data* ####

# %%
print(esoData.isnull().sum())

esoData = esoData.dropna()

print("AFTER")
print(esoData.isnull().sum())
# Out:
# 1Time            1
# 1flow            1
# 1pao             1
# 1peso            1
# 1pgastric        1
#                 ..
# 8ModifiedFlow    1
# 8ModifiedPao     1
# 8ModifiedPeso    1
# 8TimeMinRel      1
# 8TimeMinAbs      1
# Length: 96, dtype: int64
# AFTER
# 1Time            0
# 1flow            0
# 1pao             0
# 1peso            0
# 1pgastric        0
#                 ..
# 8ModifiedFlow    0
# 8ModifiedPao     0
# 8ModifiedPeso    0
# 8TimeMinRel      0
# 8TimeMinAbs      0
# Length: 96, dtype: int64

# %% [markdown]
# ## Defining Cost Function ##

# %%
#comp_halp.compliance_cost()

# %% [markdown]
# #### *Divide data into bins according to breath average* ####
# *For evaluation purposes, the data will be divided into bins for each breath*

# %%
#comp_halp.bin_divider()

# %% [markdown]
# #### *Evaluating form of loss function* ####
# Via grid search

# %%
#comp_halp.grid_search()

# %% [markdown]
# ## Testing the full monty

# %%
Corrupted_Patients = [2,3,4,5,6,7,8,9,12,16,17,19,20,21]

# %%
#Amt of patients
color = comp_halp.color
hk_patient = {}
hk_cost_form = {}
patients = 22
for patient in range(1,patients+1):
    if patient not in Corrupted_Patients:
        if patient == 11:
            
            #Load individual patient data
            print(color.BOLD +  f"Current Patient: {patient}"  + color.END)
            breathD, esoData, FFFT = halp.patientManager(patient,"entire")
            print("Data Loaded")
            #Filter data
            esoData = comp_halp.data_Filtering(esoData,verbose=True)
            print("Data Filtered")
            #Divide into bins
            esoData_bins = comp_halp.bin_divider(esoData,breathD,verbose=False)
            print("esoData bin divided")
            #Perform grid search
            hk_patient[patient] = comp_halp.grid_search(esoData, esoData_bins,breathD,patient,verbose=False)
# Out:
# Current Patient: 11
# Data Loaded
# data_Filtering created parts
# data_Filtering made it to part 1 of 9
# total iterations of moving_median: 0
# total iterations of moving_median: 10000
# total iterations of moving_median: 20000
# total iterations of moving_median: 30000
# data_Filtering completed median
# Moving average operation performed at index 500
# Moving average operation performed at index 1900
# Moving average operation performed at index 2100
# Moving average operation performed at index 3400
# Moving average operation performed at index 3800
# Moving average operation performed at index 4300
# Moving average operation performed at index 4700
# Moving average operation performed at index 5000
# Moving average operation performed at index 5400
# Moving average operation performed at index 5800
# Moving average operation performed at index 6200
# Moving average operation performed at index 7400
# Moving average operation performed at index 8800
# Moving average operation performed at index 9300
# Moving average operation performed at index 10100
# Moving average operation performed at index 11000
# Moving average operation performed at index 11100
# Moving average operation performed at index 11600
# Moving average operation performed at index 12000
# Moving average operation performed at index 12400
# Moving average operation performed at index 13800
# Moving average operation performed at index 14100
# Moving average operation performed at index 14900
# Moving average operation performed at index 15800
# Moving average operation performed at index 16200
# Moving average operation performed at index 19900
# Moving average operation performed at index 20300
# Moving average operation performed at index 20800
# Moving average operation performed at index 21400
# Moving average operation performed at index 23300
# Moving average operation performed at index 24500
# Moving average operation performed at index 25000
# Moving average operation performed at index 26100
# Moving average operation performed at index 27100
# Moving average operation performed at index 27400
# Moving average operation performed at index 27900
# Moving average operation performed at index 28300
# Moving average operation performed at index 28900
# Moving average operation performed at index 29400
# Moving average operation performed at index 29900
# Moving average operation performed at index 30800
# Moving average operation performed at index 30900
# Moving average operation performed at index 31300
# Moving average operation performed at index 31700
# Moving average operation performed at index 32200
# Moving average operation performed at index 33400
# Moving average operation performed at index 33900
# Moving average operation performed at index 34400
# Moving average operation performed at index 34800
# Moving average operation performed at index 35200
# data_Filtering completed average
#
# data_Filtering made it to part 2 of 9
# total iterations of moving_median: 0
# total iterations of moving_median: 10000
# total iterations of moving_median: 20000
# total iterations of moving_median: 30000
# data_Filtering completed median
# Moving average operation performed at index 700
# Moving average operation performed at index 1100
# Moving average operation performed at index 3100
# Moving average operation performed at index 5800
# Moving average operation performed at index 6900
# Moving average operation performed at index 10200
# Moving average operation performed at index 12800
# Moving average operation performed at index 14100
# Moving average operation performed at index 16000
# Moving average operation performed at index 16800
# Moving average operation performed at index 17300
# Moving average operation performed at index 17700
# Moving average operation performed at index 18700
# Moving average operation performed at index 20100
# Moving average operation performed at index 20900
# Moving average operation performed at index 22500
# Moving average operation performed at index 23800
# Moving average operation performed at index 24700
# Moving average operation performed at index 25300
# Moving average operation performed at index 25800
# Moving average operation performed at index 29400
# Moving average operation performed at index 29900
# Moving average operation performed at index 31500
# Moving average operation performed at index 33100
# Moving average operation performed at index 33600
# Moving average operation performed at index 34100
# Moving average operation performed at index 34700
# Moving average operation performed at index 35400
# data_Filtering completed average
#
# data_Filtering made it to part 3 of 9
# total iterations of moving_median: 0
# total iterations of moving_median: 10000
# total iterations of moving_median: 20000
# total iterations of moving_median: 30000
# data_Filtering completed median
# Moving average operation performed at index 1400
# Moving average operation performed at index 3200
# Moving average operation performed at index 4000
# Moving average operation performed at index 4500
# Moving average operation performed at index 5300
# Moving average operation performed at index 5800
# Moving average operation performed at index 6400
# Moving average operation performed at index 8300
# Moving average operation performed at index 8700
# Moving average operation performed at index 9400
# Moving average operation performed at index 9800
# Moving average operation performed at index 11600
# Moving average operation performed at index 12800
# Moving average operation performed at index 15200
# Moving average operation performed at index 15800
# Moving average operation performed at index 17800
# Moving average operation performed at index 21200
# Moving average operation performed at index 24000
# Moving average operation performed at index 24600
# Moving average operation performed at index 26500
# Moving average operation performed at index 29500
# Moving average operation performed at index 31100
# Moving average operation performed at index 32900
# Moving average operation performed at index 33700
# Moving average operation performed at index 35500
# data_Filtering completed average
#
# data_Filtering made it to part 4 of 9
# total iterations of moving_median: 0
# total iterations of moving_median: 10000
# total iterations of moving_median: 20000
# total iterations of moving_median: 30000
# data_Filtering completed median
# Moving average operation performed at index 1400
# Moving average operation performed at index 1500
# Moving average operation performed at index 1600
# Moving average operation performed at index 4200
# Moving average operation performed at index 9000
# Moving average operation performed at index 10100
# Moving average operation performed at index 13000
# Moving average operation performed at index 13600
# Moving average operation performed at index 13700
# Moving average operation performed at index 15600
# Moving average operation performed at index 17100
# Moving average operation performed at index 17400
# Moving average operation performed at index 19900
# Moving average operation performed at index 21000
# Moving average operation performed at index 21700
# Moving average operation performed at index 22400
# Moving average operation performed at index 25000
# Moving average operation performed at index 26400
# Moving average operation performed at index 26900
# Moving average operation performed at index 29400
# Moving average operation performed at index 30700
# Moving average operation performed at index 31100
# Moving average operation performed at index 32300
# Moving average operation performed at index 32900
# Moving average operation performed at index 34800
# data_Filtering completed average
#
# data_Filtering made it to part 5 of 9
# total iterations of moving_median: 0
# total iterations of moving_median: 10000
# total iterations of moving_median: 20000
# total iterations of moving_median: 30000
# data_Filtering completed median
# Moving average operation performed at index 600
# Moving average operation performed at index 1100
# Moving average operation performed at index 1200
# Moving average operation performed at index 1800
# Moving average operation performed at index 2400
# Moving average operation performed at index 3100
# Moving average operation performed at index 4100
# Moving average operation performed at index 5600
# Moving average operation performed at index 6200
# Moving average operation performed at index 6800
# Moving average operation performed at index 7600
# Moving average operation performed at index 9100
# Moving average operation performed at index 9700
# Moving average operation performed at index 10400
# Moving average operation performed at index 10900
# Moving average operation performed at index 11400
# Moving average operation performed at index 12000
# Moving average operation performed at index 14200
# Moving average operation performed at index 15100
# Moving average operation performed at index 15600
# Moving average operation performed at index 16000
# Moving average operation performed at index 17400
# Moving average operation performed at index 18300
# Moving average operation performed at index 19600
# Moving average operation performed at index 20200
# Moving average operation performed at index 21700
# Moving average operation performed at index 22200
# Moving average operation performed at index 22800
# Moving average operation performed at index 23700
# Moving average operation performed at index 24100
# Moving average operation performed at index 24700
# Moving average operation performed at index 27900
# Moving average operation performed at index 28500
# Moving average operation performed at index 32400
# Moving average operation performed at index 34800
# Moving average operation performed at index 35600
# data_Filtering completed average
#
# data_Filtering made it to part 6 of 9
# total iterations of moving_median: 0
# total iterations of moving_median: 10000
# total iterations of moving_median: 20000
# total iterations of moving_median: 30000
# data_Filtering completed median
# Moving average operation performed at index 1700
# Moving average operation performed at index 2300
# Moving average operation performed at index 2800
# Moving average operation performed at index 3400
# Moving average operation performed at index 4400
# Moving average operation performed at index 5500
# Moving average operation performed at index 6000
# Moving average operation performed at index 7300
# Moving average operation performed at index 9800
# Moving average operation performed at index 10700
# Moving average operation performed at index 11200
# Moving average operation performed at index 11700
# Moving average operation performed at index 12400
# Moving average operation performed at index 12900
# Moving average operation performed at index 15000
# Moving average operation performed at index 15700
# Moving average operation performed at index 16700
# Moving average operation performed at index 17200
# Moving average operation performed at index 18200
# Moving average operation performed at index 18800
# Moving average operation performed at index 19300
# Moving average operation performed at index 19900
# Moving average operation performed at index 25300
# Moving average operation performed at index 26500
# Moving average operation performed at index 28000
# Moving average operation performed at index 28500
# Moving average operation performed at index 29100
# Moving average operation performed at index 31900
# Moving average operation performed at index 32800
# Moving average operation performed at index 33500
# Moving average operation performed at index 34300
# Moving average operation performed at index 34700
# Moving average operation performed at index 35800
# data_Filtering completed average
#
# data_Filtering made it to part 7 of 9
# total iterations of moving_median: 0
# total iterations of moving_median: 10000
# total iterations of moving_median: 20000
# total iterations of moving_median: 30000
# data_Filtering completed median
# Moving average operation performed at index 300
# Moving average operation performed at index 1600
# Moving average operation performed at index 2000
# Moving average operation performed at index 3000
# Moving average operation performed at index 4100
# Moving average operation performed at index 6600
# Moving average operation performed at index 7300
# Moving average operation performed at index 8800
# Moving average operation performed at index 10000
# Moving average operation performed at index 12600
# Moving average operation performed at index 13200
# Moving average operation performed at index 13900
# Moving average operation performed at index 16000
# Moving average operation performed at index 16600
# Moving average operation performed at index 19300
# Moving average operation performed at index 19900
# Moving average operation performed at index 20300
# Moving average operation performed at index 24600
# Moving average operation performed at index 25200
# Moving average operation performed at index 26300
# Moving average operation performed at index 26800
# Moving average operation performed at index 27400
# Moving average operation performed at index 28000
# Moving average operation performed at index 28600
# Moving average operation performed at index 29300
# Moving average operation performed at index 29900
# Moving average operation performed at index 30500
# Moving average operation performed at index 32400
# Moving average operation performed at index 33100
# Moving average operation performed at index 35000
# Moving average operation performed at index 35600
# data_Filtering completed average
#
# data_Filtering made it to part 8 of 9
# total iterations of moving_median: 0
# total iterations of moving_median: 10000
# total iterations of moving_median: 20000
# total iterations of moving_median: 30000
# data_Filtering completed median
# Moving average operation performed at index 400
# Moving average operation performed at index 1300
# Moving average operation performed at index 1600
# Moving average operation performed at index 2900
# Moving average operation performed at index 7100
# Moving average operation performed at index 10400
# Moving average operation performed at index 11000
# Moving average operation performed at index 11600
# Moving average operation performed at index 12300
# Moving average operation performed at index 13000
# Moving average operation performed at index 16100
# Moving average operation performed at index 18600
# Moving average operation performed at index 19800
# Moving average operation performed at index 20300
# Moving average operation performed at index 20900
# Moving average operation performed at index 22200
# Moving average operation performed at index 25600
# Moving average operation performed at index 27500
# Moving average operation performed at index 28100
# Moving average operation performed at index 28700
# Moving average operation performed at index 29300
# Moving average operation performed at index 30000
# Moving average operation performed at index 30700
# Moving average operation performed at index 32000
# Moving average operation performed at index 33400
# Moving average operation performed at index 34300
# Moving average operation performed at index 34800
# data_Filtering completed average
#
# Data Filtered
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 18
#      16 print("Data Filtered")
#      17 #Divide into bins
# ---> 18 esoData_bins = comp_halp.bin_divider(esoData,breathD,verbose=False)
#      19 print("esoData bin divided")
#      20 #Perform grid search
#
# TypeError: bin_divider() missing 1 required positional argument: 'PEEP'

# %%
hk_patient[11][1]['hk_breath'][7]['cost_form']

# %%
type(hk_patient[11][1]['hk_breath'][7]['cost_form'])

# %%
C_range = np.arange(100,400,0.5)
C_range[1]

# %%
C_range = np.arange(100,400,0.5)
pd_dict = hk_patient[11][1]['hk_breath'][7]['cost_form']
df = pd.DataFrame(columns=['C','j'], index = range(len(C_range)))

for c in range(len(C_range)):
    df.at[c,"C"] = C_range[c]
    df.at[c,"j"] = pd_dict[C_range[c]]

# %%
px.scatter(x=df['C'],y=df['j'])
