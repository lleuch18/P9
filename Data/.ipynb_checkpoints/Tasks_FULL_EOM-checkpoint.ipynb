# %% [markdown]
# # Imports

# %%
import plotly.express as px
import pandas as pd
import numpy as np
import Data_Explo_HELPER as halp
import Compl_Algo_Helper as comp_halp

# %% [markdown]
# # Calculate Raw
# ### Requires
# * Expiratory Time Constant
# * Peak insipiratory flow and PIP
# * Pplat

# %%
# Calculate Pplat from method described in article 1776

#Formula
def Pplat_method(Vt,PIP,PEEP,exp_t_const,mean_insp_flow):
    Pplat = ((Vt*PIP)-(Vt*PEEP))/Vt+(exp_t_const*mean_insp_flow)

    return Pplat

# %%
#Set patient
patient = 11

#load data
breathD,esoData,FFFT = halp.patientManager(patient,'entire')

parts = int(len(esoData.columns)/12)+1

for part in range(1,parts):
    # Calculate Expiratory Time Constant
    prefix = str(part)
    Vt,Vtexp,inspStart,expStart,ModifiedFlow,peak_exp_flow,exp_t_const,mean_insp_flow,ModifiedPao,PIP,Pplat,Raw_exp,Raw_insp = halp.prefix_Factory(part,
                                                                           'Vt',
                                                                           'Vtexp',
                                                                           'inspStart',
                                                                           'expStart',
                                                                           'ModifiedFlow',
                                                                           'peak_exp_flow',
                                                                           'exp_t_const',
                                                                           'MeanInspFlow',
                                                                           'ModifiedPao',
                                                                           'PIP',
                                                                           'Pplat',
                                                                           'Raw_exp',
                                                                           'Raw_insp'
                                                                           )


    #Load vent settings
    PS, PEEP = halp.Ventilator().get_Settings(patient)
    PEEP = PEEP[part]


    #Breath amt is length once NaN have been dropped
    b_amt = len(breathD[Vtexp].dropna())-1

    for breath in range(1,b_amt):
        #Get Vt_exp
        exp_Vt = breathD.at[breath-1,Vtexp]*100
        #print(f"exp_Vt at {breath} is {exp_Vt}")
        #get start index and expiratory length
        start_exp = breathD.at[breath,expStart]
        len_exp = breathD.at[breath+1,inspStart] - breathD.at[breath,expStart]
        #Calculate peak flow for the breath
        breathD.at[breath,peak_exp_flow] = esoData.loc[start_exp:(start_exp+len_exp),ModifiedFlow].max()
        print(f"Peak Exp Flow at {breath} is {breathD.at[breath,peak_exp_flow]}")
        #Calculate exp_t_const
        breathD.at[breath,exp_t_const] = exp_Vt/breathD.at[breath,peak_exp_flow]
        #print(f"exp_t_const at {breath} is {breathD.at[breath,exp_t_const]}")

    # Calculate peak flow and PIP
    for breath in range(1,b_amt):
        start_insp = breathD.at[breath,inspStart]
        len_insp = breathD.at[breath+1,expStart] - breathD.at[breath,inspStart]

        breathD.at[breath,mean_insp_flow] = esoData.loc[start_insp:(start_insp+len_insp),ModifiedFlow].mean()
        breathD.at[breath,PIP] = esoData.loc[start_insp:(start_insp+len_insp),ModifiedPao].max()


    # Calculate Pplat from method described in article 1776
    for breath in range(1,b_amt):
        breathD.at[breath,Pplat] = Pplat_method(breathD.at[breath,Vt],
                                             breathD.at[breath,PIP],
                                             PEEP,
                                             breathD.at[breath,exp_t_const],
                                             breathD.at[breath,mean_insp_flow]
                                             )


    # Calculate Raw
    #Raw = (PIP-Pplat)/Flow
    for breath in range(1,b_amt):
        breathD.at[breath,Raw_insp] = (breathD.at[breath,PIP]-breathD.at[breath,Pplat])/breathD.at[breath,mean_insp_flow]
        breathD.at[breath,Raw_exp] = (breathD.at[breath,PIP]-breathD.at[breath,Pplat])/breathD.at[breath,peak_exp_flow]
# Out:
# NOTE: For patient 5, 16 and 21, missing values have been imputated
# The imputated values are are:
# Patient 5: part 3
# Patient 16: part 4
# Patient 21: part 2
# Peak Exp Flow at 1 is 17.19
# Peak Exp Flow at 2 is 17.19
# Peak Exp Flow at 3 is -0.57
# Peak Exp Flow at 4 is 14.79
# Peak Exp Flow at 5 is 15.63
# Peak Exp Flow at 6 is 15.63
# Peak Exp Flow at 7 is 19.23
# Peak Exp Flow at 8 is 21.42
# Peak Exp Flow at 9 is 21.42
# Peak Exp Flow at 10 is 17.01
# Peak Exp Flow at 11 is 17.01
# Peak Exp Flow at 12 is 20.58
# Peak Exp Flow at 13 is 20.58
# Peak Exp Flow at 14 is 19.68
# Peak Exp Flow at 15 is 19.68
# Peak Exp Flow at 16 is 19.59
# Peak Exp Flow at 17 is 19.59
# Peak Exp Flow at 18 is 17.64
# Peak Exp Flow at 19 is 19.38
# Peak Exp Flow at 20 is 19.2
# Peak Exp Flow at 21 is 16.32
# Peak Exp Flow at 22 is 16.53
# Peak Exp Flow at 23 is 18.39
# Peak Exp Flow at 24 is 18.03
# Peak Exp Flow at 25 is 18.96
# Peak Exp Flow at 26 is 18.96
# Peak Exp Flow at 27 is 20.28
# Peak Exp Flow at 28 is 21.09
# Peak Exp Flow at 29 is 14.28
# Peak Exp Flow at 30 is 14.25
# Peak Exp Flow at 31 is 15.3
# Peak Exp Flow at 32 is 13.59
# Peak Exp Flow at 33 is 17.01
# Peak Exp Flow at 34 is 17.01
# Peak Exp Flow at 35 is 21.36
# Peak Exp Flow at 36 is 21.36
# Peak Exp Flow at 37 is 11.46
# Peak Exp Flow at 38 is 8.49000000000001
# Peak Exp Flow at 39 is 8.49000000000001
# Peak Exp Flow at 40 is -0.42
# Peak Exp Flow at 41 is 25.02
# Peak Exp Flow at 42 is 25.02
# Peak Exp Flow at 43 is 21.39
# Peak Exp Flow at 44 is 21.39
# Peak Exp Flow at 45 is -0.87
# Peak Exp Flow at 46 is 23.85
# Peak Exp Flow at 47 is 23.85
# Peak Exp Flow at 48 is 18.69
# Peak Exp Flow at 49 is 0.12
# Peak Exp Flow at 50 is 14.07
# Peak Exp Flow at 51 is 14.07
# Peak Exp Flow at 52 is 0.69
# Peak Exp Flow at 53 is 13.44
# Peak Exp Flow at 54 is 22.41
# Peak Exp Flow at 55 is 22.41
# Peak Exp Flow at 56 is 20.97
# Peak Exp Flow at 57 is 10.62
# Peak Exp Flow at 58 is 17.31
# Peak Exp Flow at 59 is 17.31
# Peak Exp Flow at 60 is 16.89
# Peak Exp Flow at 61 is 16.89
# Peak Exp Flow at 62 is 10.56
# Peak Exp Flow at 63 is 19.92
# Peak Exp Flow at 64 is 19.92
# Peak Exp Flow at 65 is 13.53
# Peak Exp Flow at 66 is 18.78
# Peak Exp Flow at 67 is 18.78
# Peak Exp Flow at 68 is 18.21
# Peak Exp Flow at 69 is 20.04
# Peak Exp Flow at 70 is 20.04
# Peak Exp Flow at 71 is 17.43
# Peak Exp Flow at 72 is 19.68
# Peak Exp Flow at 73 is 19.68
# Peak Exp Flow at 74 is 17.76
# Peak Exp Flow at 75 is 19.53
# Peak Exp Flow at 76 is 19.53
# Peak Exp Flow at 77 is 18.0
# Peak Exp Flow at 78 is 21.3
# Peak Exp Flow at 79 is 21.3
# Peak Exp Flow at 80 is 21.24
# Peak Exp Flow at 81 is 21.24
# Peak Exp Flow at 82 is 18.78
# Peak Exp Flow at 83 is 22.11
# Peak Exp Flow at 84 is 20.67
# Peak Exp Flow at 85 is -2.82
# Peak Exp Flow at 86 is 21.21
# Peak Exp Flow at 87 is 21.21
# Peak Exp Flow at 88 is 22.2
# Peak Exp Flow at 89 is 22.2
# Peak Exp Flow at 90 is 17.52
# Peak Exp Flow at 91 is 21.42
# Peak Exp Flow at 92 is 20.79
# Peak Exp Flow at 93 is 20.1
# Peak Exp Flow at 94 is 16.02
# Peak Exp Flow at 95 is 16.08
# Peak Exp Flow at 96 is 19.62
# Peak Exp Flow at 97 is 19.62
# Peak Exp Flow at 98 is 18.15
# Peak Exp Flow at 99 is 18.15
# Peak Exp Flow at 100 is 20.79
# Peak Exp Flow at 101 is 20.79
# Peak Exp Flow at 102 is 19.56
# Peak Exp Flow at 103 is 20.43
# Peak Exp Flow at 104 is 20.43
# Peak Exp Flow at 105 is 22.77
# Peak Exp Flow at 106 is 22.77
# Peak Exp Flow at 107 is 20.4
# Peak Exp Flow at 108 is 20.4
# Peak Exp Flow at 109 is -0.36
# Peak Exp Flow at 110 is -0.3
# Peak Exp Flow at 111 is 20.34
# Peak Exp Flow at 112 is 22.05
# Peak Exp Flow at 113 is 21.99
# Peak Exp Flow at 114 is -1.32
# Peak Exp Flow at 115 is 21.51
# Peak Exp Flow at 116 is 21.51
# Peak Exp Flow at 117 is 21.36
# Peak Exp Flow at 118 is 21.36
# Peak Exp Flow at 119 is -0.36
# Peak Exp Flow at 120 is 22.05
# Peak Exp Flow at 121 is 22.05
# Peak Exp Flow at 122 is 21.9
# Peak Exp Flow at 123 is 21.9
# Peak Exp Flow at 124 is 18.57
# Peak Exp Flow at 125 is 21.84
# Peak Exp Flow at 126 is 20.64
# Peak Exp Flow at 127 is 16.95
# Peak Exp Flow at 128 is 19.77
# Peak Exp Flow at 129 is 19.77
# Peak Exp Flow at 130 is 15.81
# Peak Exp Flow at 131 is 15.81
# Peak Exp Flow at 132 is 16.2
# Peak Exp Flow at 133 is 16.2
# Peak Exp Flow at 134 is 14.25
# Peak Exp Flow at 135 is 19.38
# Peak Exp Flow at 136 is 19.38
# Peak Exp Flow at 137 is -0.6
# Peak Exp Flow at 138 is 20.58
# Peak Exp Flow at 139 is 20.58
# Peak Exp Flow at 140 is -2.52
# Peak Exp Flow at 141 is 21.06
# Peak Exp Flow at 142 is 21.06
# Peak Exp Flow at 143 is -5.31
# Peak Exp Flow at 144 is 18.48
# Peak Exp Flow at 145 is 20.85
# Peak Exp Flow at 146 is 18.84
# Peak Exp Flow at 147 is -0.84
# Peak Exp Flow at 148 is 20.64
# Peak Exp Flow at 149 is 22.02
# Peak Exp Flow at 150 is 22.02
# Peak Exp Flow at 151 is 17.07
# Peak Exp Flow at 152 is 17.07
# Peak Exp Flow at 153 is 16.2
# Peak Exp Flow at 154 is 16.2
# Peak Exp Flow at 155 is 16.38
# Peak Exp Flow at 156 is 16.8
# Peak Exp Flow at 157 is -0.24
# Peak Exp Flow at 158 is 17.37
# Peak Exp Flow at 159 is 17.52
# Peak Exp Flow at 160 is 15.54
# Peak Exp Flow at 161 is -1.14
# Peak Exp Flow at 162 is 18.66
# Peak Exp Flow at 163 is 18.63
# Peak Exp Flow at 164 is -0.48
# Peak Exp Flow at 165 is 18.84
# Peak Exp Flow at 166 is 18.75
# Peak Exp Flow at 167 is 19.14
# Peak Exp Flow at 168 is 19.14
# Peak Exp Flow at 169 is -1.47
# Peak Exp Flow at 170 is 16.44
# Peak Exp Flow at 171 is 16.44
# Peak Exp Flow at 172 is 16.35
# Peak Exp Flow at 173 is 17.25
# Peak Exp Flow at 174 is 14.94
# NOTE: For patient 5, 16 and 21, missing values have been imputated
# The imputated values are are:
# Patient 5: part 3
# Patient 16: part 4
# Patient 21: part 2
# Peak Exp Flow at 1 is 21.81
# Peak Exp Flow at 2 is 21.81
# Peak Exp Flow at 3 is 25.68
# Peak Exp Flow at 4 is 25.68
# Peak Exp Flow at 5 is 25.95
# Peak Exp Flow at 6 is 25.95
# Peak Exp Flow at 7 is 24.96
# Peak Exp Flow at 8 is 25.56
# Peak Exp Flow at 9 is 25.56
# Peak Exp Flow at 10 is 11.94
# Peak Exp Flow at 11 is 24.66
# Peak Exp Flow at 12 is 24.51
# Peak Exp Flow at 13 is -0.48
# Peak Exp Flow at 14 is -0.12
# Peak Exp Flow at 15 is 26.43
# Peak Exp Flow at 16 is 26.43
# Peak Exp Flow at 17 is 19.8
# Peak Exp Flow at 18 is 19.8
# Peak Exp Flow at 19 is 25.29
# Peak Exp Flow at 20 is 25.29
# Peak Exp Flow at 21 is 24.3
# Peak Exp Flow at 22 is 24.3
# Peak Exp Flow at 23 is 24.51
# Peak Exp Flow at 24 is 24.57
# Peak Exp Flow at 25 is 19.41
# Peak Exp Flow at 26 is 22.29
# Peak Exp Flow at 27 is 22.29
# Peak Exp Flow at 28 is 26.4
# Peak Exp Flow at 29 is 26.4
# Peak Exp Flow at 30 is 11.07
# Peak Exp Flow at 31 is 24.93
# Peak Exp Flow at 32 is 24.72
# Peak Exp Flow at 33 is 25.26
# Peak Exp Flow at 34 is 25.26
# Peak Exp Flow at 35 is 25.83
# Peak Exp Flow at 36 is 25.83
# Peak Exp Flow at 37 is 17.73
# Peak Exp Flow at 38 is 23.88
# Peak Exp Flow at 39 is 23.88
# Peak Exp Flow at 40 is 19.53
# Peak Exp Flow at 41 is 19.53
# Peak Exp Flow at 42 is 23.01
# Peak Exp Flow at 43 is 25.05
# Peak Exp Flow at 44 is 25.05
# Peak Exp Flow at 45 is -0.63
# Peak Exp Flow at 46 is 23.04
# Peak Exp Flow at 47 is 23.04
# Peak Exp Flow at 48 is 26.94
# Peak Exp Flow at 49 is 26.94
# Peak Exp Flow at 50 is 26.22
# Peak Exp Flow at 51 is 26.22
# Peak Exp Flow at 52 is 24.6
# Peak Exp Flow at 53 is 16.83
# Peak Exp Flow at 54 is -1.35
# Peak Exp Flow at 55 is 18.72
# Peak Exp Flow at 56 is 18.72
# Peak Exp Flow at 57 is 19.38
# Peak Exp Flow at 58 is 16.77
# Peak Exp Flow at 59 is 17.97
# Peak Exp Flow at 60 is 17.73
# Peak Exp Flow at 61 is 17.73
# Peak Exp Flow at 62 is 21.27
# Peak Exp Flow at 63 is 21.27
# Peak Exp Flow at 64 is -2.88
# Peak Exp Flow at 65 is 23.16
# Peak Exp Flow at 66 is 23.16
# Peak Exp Flow at 67 is 23.55
# Peak Exp Flow at 68 is 23.55
# Peak Exp Flow at 69 is 23.67
# Peak Exp Flow at 70 is 23.43
# Peak Exp Flow at 71 is 23.88
# Peak Exp Flow at 72 is 23.88
# Peak Exp Flow at 73 is 24.78
# Peak Exp Flow at 74 is 24.78
# Peak Exp Flow at 75 is 25.86
# Peak Exp Flow at 76 is 25.86
# Peak Exp Flow at 77 is 23.22
# Peak Exp Flow at 78 is 23.22
# Peak Exp Flow at 79 is 20.49
# Peak Exp Flow at 80 is 20.49
# Peak Exp Flow at 81 is 22.17
# Peak Exp Flow at 82 is 22.17
# Peak Exp Flow at 83 is 23.31
# Peak Exp Flow at 84 is 23.31
# Peak Exp Flow at 85 is 23.16
# Peak Exp Flow at 86 is 20.58
# Peak Exp Flow at 87 is -1.53
# Peak Exp Flow at 88 is 23.67
# Peak Exp Flow at 89 is 23.67
# Peak Exp Flow at 90 is 22.11
# Peak Exp Flow at 91 is 22.11
# Peak Exp Flow at 92 is 23.79
# Peak Exp Flow at 93 is 23.64
# Peak Exp Flow at 94 is 23.94
# Peak Exp Flow at 95 is 25.86
# Peak Exp Flow at 96 is 23.55
# Peak Exp Flow at 97 is 23.64
# Peak Exp Flow at 98 is 23.64
# Peak Exp Flow at 99 is 24.96
# Peak Exp Flow at 100 is 24.96
# Peak Exp Flow at 101 is 21.9
# Peak Exp Flow at 102 is 24.15
# Peak Exp Flow at 103 is 24.54
# Peak Exp Flow at 104 is 25.47
# Peak Exp Flow at 105 is 25.47
# Peak Exp Flow at 106 is -0.48
# Peak Exp Flow at 107 is 24.24
# Peak Exp Flow at 108 is 24.24
# Peak Exp Flow at 109 is 21.09
# Peak Exp Flow at 110 is 19.44
# Peak Exp Flow at 111 is 19.44
# Peak Exp Flow at 112 is 19.17
# Peak Exp Flow at 113 is 19.17
# Peak Exp Flow at 114 is 19.83
# Peak Exp Flow at 115 is 19.83
# Peak Exp Flow at 116 is 21.09
# Peak Exp Flow at 117 is 20.37
# Peak Exp Flow at 118 is 23.37
# Peak Exp Flow at 119 is 22.74
# Peak Exp Flow at 120 is 20.07
# Peak Exp Flow at 121 is 24.18
# Peak Exp Flow at 122 is 24.18
# Peak Exp Flow at 123 is 23.76
# Peak Exp Flow at 124 is 23.76
# Peak Exp Flow at 125 is 22.02
# Peak Exp Flow at 126 is 22.02
# Peak Exp Flow at 127 is 24.12
# Peak Exp Flow at 128 is 24.12
# Peak Exp Flow at 129 is 22.56
# Peak Exp Flow at 130 is 22.56
# Peak Exp Flow at 131 is 23.73
# Peak Exp Flow at 132 is 23.73
# Peak Exp Flow at 133 is 24.63
# Peak Exp Flow at 134 is 24.63
# Peak Exp Flow at 135 is 22.74
# Peak Exp Flow at 136 is 22.74
# Peak Exp Flow at 137 is 25.41
# Peak Exp Flow at 138 is 25.41
# Peak Exp Flow at 139 is -0.72
# Peak Exp Flow at 140 is 21.99
# NOTE: For patient 5, 16 and 21, missing values have been imputated
# The imputated values are are:
# Patient 5: part 3
# Patient 16: part 4
# Patient 21: part 2
# Peak Exp Flow at 1 is 24.69
# Peak Exp Flow at 2 is 24.69
# Peak Exp Flow at 3 is 10.5
# Peak Exp Flow at 4 is 25.32
# Peak Exp Flow at 5 is 25.32
# Peak Exp Flow at 6 is 24.21
# Peak Exp Flow at 7 is 24.21
# Peak Exp Flow at 8 is 25.11
# Peak Exp Flow at 9 is 25.11
# Peak Exp Flow at 10 is 25.11
# Peak Exp Flow at 11 is 25.11
# Peak Exp Flow at 12 is 18.18
# Peak Exp Flow at 13 is 24.78
# Peak Exp Flow at 14 is 15.75
# Peak Exp Flow at 15 is -0.03
# Peak Exp Flow at 16 is 26.07
# Peak Exp Flow at 17 is 26.07
# Peak Exp Flow at 18 is 22.11
# Peak Exp Flow at 19 is 13.86
# Peak Exp Flow at 20 is 24.51
# Peak Exp Flow at 21 is 24.51
# Peak Exp Flow at 22 is 21.72
# Peak Exp Flow at 23 is 21.72
# Peak Exp Flow at 24 is 15.3
# Peak Exp Flow at 25 is 14.58
# Peak Exp Flow at 26 is 13.71
# Peak Exp Flow at 27 is 23.16
# Peak Exp Flow at 28 is 23.16
# Peak Exp Flow at 29 is 18.09
# Peak Exp Flow at 30 is 18.09
# Peak Exp Flow at 31 is 16.08
# Peak Exp Flow at 32 is 20.58
# Peak Exp Flow at 33 is 19.14
# Peak Exp Flow at 34 is 18.33
# Peak Exp Flow at 35 is 24.24
# Peak Exp Flow at 36 is 24.24
# Peak Exp Flow at 37 is 24.18
# Peak Exp Flow at 38 is 24.18
# Peak Exp Flow at 39 is 23.13
# Peak Exp Flow at 40 is 23.22
# Peak Exp Flow at 41 is 24.03
# Peak Exp Flow at 42 is 24.03
# Peak Exp Flow at 43 is 27.12
# Peak Exp Flow at 44 is 27.12
# Peak Exp Flow at 45 is 25.71
# Peak Exp Flow at 46 is 25.71
# Peak Exp Flow at 47 is -5.58
# Peak Exp Flow at 48 is -4.26
# Peak Exp Flow at 49 is -2.82
# Peak Exp Flow at 50 is -0.63
# Peak Exp Flow at 51 is 22.14
# Peak Exp Flow at 52 is 22.14
# Peak Exp Flow at 53 is -1.56
# Peak Exp Flow at 54 is 25.95
# Peak Exp Flow at 55 is 26.22
# Peak Exp Flow at 56 is 8.66999999999999
# Peak Exp Flow at 57 is 26.34
# Peak Exp Flow at 58 is 26.34
# Peak Exp Flow at 59 is 19.41
# Peak Exp Flow at 60 is 24.54
# Peak Exp Flow at 61 is 24.54
# Peak Exp Flow at 62 is 23.67
# Peak Exp Flow at 63 is 23.67
# Peak Exp Flow at 64 is 25.56
# Peak Exp Flow at 65 is 25.56
# Peak Exp Flow at 66 is 27.39
# Peak Exp Flow at 67 is 27.39
# Peak Exp Flow at 68 is 23.76
# Peak Exp Flow at 69 is 25.95
# Peak Exp Flow at 70 is 26.49
# Peak Exp Flow at 71 is 4.17
# Peak Exp Flow at 72 is 24.81
# Peak Exp Flow at 73 is 24.81
# Peak Exp Flow at 74 is 24.69
# Peak Exp Flow at 75 is 24.69
# Peak Exp Flow at 76 is 26.46
# Peak Exp Flow at 77 is 26.46
# Peak Exp Flow at 78 is 25.56
# Peak Exp Flow at 79 is 25.56
# Peak Exp Flow at 80 is 22.5
# Peak Exp Flow at 81 is 23.34
# Peak Exp Flow at 82 is 24.69
# Peak Exp Flow at 83 is 24.51
# Peak Exp Flow at 84 is 25.35
# Peak Exp Flow at 85 is 25.35
# Peak Exp Flow at 86 is 26.28
# Peak Exp Flow at 87 is 26.28
# Peak Exp Flow at 88 is 22.5
# Peak Exp Flow at 89 is 22.5
# Peak Exp Flow at 90 is -2.52
# Peak Exp Flow at 91 is -1.62
# Peak Exp Flow at 92 is 21.96
# Peak Exp Flow at 93 is 23.28
# Peak Exp Flow at 94 is 23.28
# Peak Exp Flow at 95 is 24.15
# Peak Exp Flow at 96 is 24.15
# Peak Exp Flow at 97 is 0.09
# Peak Exp Flow at 98 is 25.77
# Peak Exp Flow at 99 is 25.77
# Peak Exp Flow at 100 is 24.51
# Peak Exp Flow at 101 is 25.14
# Peak Exp Flow at 102 is 25.14
# Peak Exp Flow at 103 is 20.85
# Peak Exp Flow at 104 is 20.85
# Peak Exp Flow at 105 is 24.51
# Peak Exp Flow at 106 is 24.51
# Peak Exp Flow at 107 is 25.26
# Peak Exp Flow at 108 is 25.26
# Peak Exp Flow at 109 is 23.34
# Peak Exp Flow at 110 is 25.83
# Peak Exp Flow at 111 is 25.83
# Peak Exp Flow at 112 is 24.54
# Peak Exp Flow at 113 is 21.45
# Peak Exp Flow at 114 is 21.45
# Peak Exp Flow at 115 is -0.24
# Peak Exp Flow at 116 is 22.2
# Peak Exp Flow at 117 is 24.84
# Peak Exp Flow at 118 is 24.84
# Peak Exp Flow at 119 is 22.8
# Peak Exp Flow at 120 is 25.71
# Peak Exp Flow at 121 is 24.42
# Peak Exp Flow at 122 is 21.9
# Peak Exp Flow at 123 is 23.61
# Peak Exp Flow at 124 is 19.44
# Peak Exp Flow at 125 is 22.14
# Peak Exp Flow at 126 is 22.14
# Peak Exp Flow at 127 is 25.8
# Peak Exp Flow at 128 is 25.8
# Peak Exp Flow at 129 is 26.04
# NOTE: For patient 5, 16 and 21, missing values have been imputated
# The imputated values are are:
# Patient 5: part 3
# Patient 16: part 4
# Patient 21: part 2
# Peak Exp Flow at 1 is 16.86
# Peak Exp Flow at 2 is 24.42
# Peak Exp Flow at 3 is 24.42
# Peak Exp Flow at 4 is 23.13
# Peak Exp Flow at 5 is 16.59
# Peak Exp Flow at 6 is 18.96
# Peak Exp Flow at 7 is 19.92
# Peak Exp Flow at 8 is 19.92
# Peak Exp Flow at 9 is 21.15
# Peak Exp Flow at 10 is 21.15
# Peak Exp Flow at 11 is -3.09
# Peak Exp Flow at 12 is 24.3
# Peak Exp Flow at 13 is 24.3
# Peak Exp Flow at 14 is 24.6
# Peak Exp Flow at 15 is 24.6
# Peak Exp Flow at 16 is 19.08
# Peak Exp Flow at 17 is 23.61
# Peak Exp Flow at 18 is 23.61
# Peak Exp Flow at 19 is 21.54
# Peak Exp Flow at 20 is 21.54
# Peak Exp Flow at 21 is 17.73
# Peak Exp Flow at 22 is 23.94
# Peak Exp Flow at 23 is 23.94
# Peak Exp Flow at 24 is 23.82
# Peak Exp Flow at 25 is 23.82
# Peak Exp Flow at 26 is 22.35
# Peak Exp Flow at 27 is 22.35
# Peak Exp Flow at 28 is 21.78
# Peak Exp Flow at 29 is 21.78
# Peak Exp Flow at 30 is 0.06
# Peak Exp Flow at 31 is 21.81
# Peak Exp Flow at 32 is 21.3
# Peak Exp Flow at 33 is 23.31
# Peak Exp Flow at 34 is 23.31
# Peak Exp Flow at 35 is -7.95
# Peak Exp Flow at 36 is -1.32
# Peak Exp Flow at 37 is 21.84
# Peak Exp Flow at 38 is 21.84
# Peak Exp Flow at 39 is 26.49
# Peak Exp Flow at 40 is 26.49
# Peak Exp Flow at 41 is -1.86
# Peak Exp Flow at 42 is 26.61
# Peak Exp Flow at 43 is 26.61
# Peak Exp Flow at 44 is 26.1
# Peak Exp Flow at 45 is 26.67
# Peak Exp Flow at 46 is 18.15
# Peak Exp Flow at 47 is 26.04
# Peak Exp Flow at 48 is 26.04
# Peak Exp Flow at 49 is -0.66
# Peak Exp Flow at 50 is 23.79
# Peak Exp Flow at 51 is 27.06
# Peak Exp Flow at 52 is 27.06
# Peak Exp Flow at 53 is 24.09
# Peak Exp Flow at 54 is 26.16
# Peak Exp Flow at 55 is 22.71
# Peak Exp Flow at 56 is 22.74
# Peak Exp Flow at 57 is 22.74
# Peak Exp Flow at 58 is -0.39
# Peak Exp Flow at 59 is 26.1
# Peak Exp Flow at 60 is 26.1
# Peak Exp Flow at 61 is 24.18
# Peak Exp Flow at 62 is 26.82
# Peak Exp Flow at 63 is 26.82
# Peak Exp Flow at 64 is 9.77999999999999
# Peak Exp Flow at 65 is 24.81
# Peak Exp Flow at 66 is 25.38
# Peak Exp Flow at 67 is 25.38
# Peak Exp Flow at 68 is 14.94
# Peak Exp Flow at 69 is 26.67
# Peak Exp Flow at 70 is 26.67
# Peak Exp Flow at 71 is 24.39
# Peak Exp Flow at 72 is 24.39
# Peak Exp Flow at 73 is 21.54
# Peak Exp Flow at 74 is 21.54
# Peak Exp Flow at 75 is 22.08
# Peak Exp Flow at 76 is 24.75
# Peak Exp Flow at 77 is 24.75
# Peak Exp Flow at 78 is 26.46
# Peak Exp Flow at 79 is 26.46
# Peak Exp Flow at 80 is 24.51
# Peak Exp Flow at 81 is 24.51
# Peak Exp Flow at 82 is 24.27
# Peak Exp Flow at 83 is 24.27
# Peak Exp Flow at 84 is 23.34
# Peak Exp Flow at 85 is 26.37
# Peak Exp Flow at 86 is 26.37
# Peak Exp Flow at 87 is 2.04
# Peak Exp Flow at 88 is 23.82
# Peak Exp Flow at 89 is 23.82
# Peak Exp Flow at 90 is 21.81
# Peak Exp Flow at 91 is 21.81
# Peak Exp Flow at 92 is 18.99
# Peak Exp Flow at 93 is 24.27
# Peak Exp Flow at 94 is 23.61
# Peak Exp Flow at 95 is 23.61
# Peak Exp Flow at 96 is 22.92
# Peak Exp Flow at 97 is 22.92
# Peak Exp Flow at 98 is 20.13
# Peak Exp Flow at 99 is 20.13
# Peak Exp Flow at 100 is 23.52
# Peak Exp Flow at 101 is 23.52
# Peak Exp Flow at 102 is 24.72
# Peak Exp Flow at 103 is 24.72
# Peak Exp Flow at 104 is 5.70000000000001
# Peak Exp Flow at 105 is 7.5
# Peak Exp Flow at 106 is 23.82
# Peak Exp Flow at 107 is 23.82
# Peak Exp Flow at 108 is 23.01
# Peak Exp Flow at 109 is 25.41
# Peak Exp Flow at 110 is 25.41
# Peak Exp Flow at 111 is 24.03
# Peak Exp Flow at 112 is 24.93
# Peak Exp Flow at 113 is 25.35
# Peak Exp Flow at 114 is 25.89
# Peak Exp Flow at 115 is 1.71
# Peak Exp Flow at 116 is 25.23
# Peak Exp Flow at 117 is 25.23
# Peak Exp Flow at 118 is 1.02
# Peak Exp Flow at 119 is 26.79
# Peak Exp Flow at 120 is 26.79
# Peak Exp Flow at 121 is 24.72
# Peak Exp Flow at 122 is 25.14
# NOTE: For patient 5, 16 and 21, missing values have been imputated
# The imputated values are are:
# Patient 5: part 3
# Patient 16: part 4
# Patient 21: part 2
# Peak Exp Flow at 1 is 24.15
# Peak Exp Flow at 2 is 24.15
# Peak Exp Flow at 3 is 22.71
# Peak Exp Flow at 4 is 22.71
# Peak Exp Flow at 5 is 23.73
# Peak Exp Flow at 6 is 23.73
# Peak Exp Flow at 7 is -0.3
# Peak Exp Flow at 8 is 24.66
# Peak Exp Flow at 9 is 24.66
# Peak Exp Flow at 10 is 25.92
# Peak Exp Flow at 11 is 25.92
# Peak Exp Flow at 12 is 24.3
# Peak Exp Flow at 13 is 25.02
# Peak Exp Flow at 14 is 25.02
# Peak Exp Flow at 15 is 24.12
# Peak Exp Flow at 16 is 24.12
# Peak Exp Flow at 17 is 26.01
# Peak Exp Flow at 18 is 26.01
# Peak Exp Flow at 19 is 23.76
# Peak Exp Flow at 20 is 23.76
# Peak Exp Flow at 21 is -1.47
# Peak Exp Flow at 22 is -0.24
# Peak Exp Flow at 23 is 26.01
# Peak Exp Flow at 24 is 26.01
# Peak Exp Flow at 25 is 0.75
# Peak Exp Flow at 26 is 24.75
# Peak Exp Flow at 27 is 25.47
# Peak Exp Flow at 28 is 20.01
# Peak Exp Flow at 29 is 24.6
# Peak Exp Flow at 30 is 24.6
# Peak Exp Flow at 31 is 25.11
# Peak Exp Flow at 32 is 25.11
# Peak Exp Flow at 33 is 24.96
# Peak Exp Flow at 34 is -0.78
# Peak Exp Flow at 35 is 24.81
# Peak Exp Flow at 36 is 24.81
# Peak Exp Flow at 37 is 23.43
# Peak Exp Flow at 38 is 23.43
# Peak Exp Flow at 39 is 22.2
# Peak Exp Flow at 40 is 23.82
# Peak Exp Flow at 41 is 24.99
# Peak Exp Flow at 42 is 25.83
# Peak Exp Flow at 43 is 21.15
# Peak Exp Flow at 44 is 25.68
# Peak Exp Flow at 45 is 24.93
# Peak Exp Flow at 46 is 4.89
# Peak Exp Flow at 47 is 19.17
# Peak Exp Flow at 48 is 21.51
# Peak Exp Flow at 49 is 21.51
# Peak Exp Flow at 50 is 18.96
# Peak Exp Flow at 51 is 18.39
# Peak Exp Flow at 52 is 18.39
# Peak Exp Flow at 53 is 21.03
# Peak Exp Flow at 54 is 18.57
# Peak Exp Flow at 55 is 18.57
# Peak Exp Flow at 56 is 24.75
# Peak Exp Flow at 57 is 24.75
# Peak Exp Flow at 58 is 25.8
# Peak Exp Flow at 59 is 25.8
# Peak Exp Flow at 60 is 20.19
# Peak Exp Flow at 61 is 23.91
# Peak Exp Flow at 62 is 23.91
# Peak Exp Flow at 63 is 23.79
# Peak Exp Flow at 64 is 24.6
# Peak Exp Flow at 65 is 24.6
# Peak Exp Flow at 66 is 21.57
# Peak Exp Flow at 67 is -0.24
# Peak Exp Flow at 68 is 0.18
# Peak Exp Flow at 69 is 21.39
# Peak Exp Flow at 70 is 23.01
# Peak Exp Flow at 71 is 23.01
# Peak Exp Flow at 72 is 22.62
# Peak Exp Flow at 73 is 22.62
# Peak Exp Flow at 74 is 0.27
# Peak Exp Flow at 75 is 22.41
# Peak Exp Flow at 76 is 22.65
# Peak Exp Flow at 77 is 22.65
# Peak Exp Flow at 78 is 20.91
# Peak Exp Flow at 79 is 20.91
# Peak Exp Flow at 80 is 23.28
# Peak Exp Flow at 81 is 23.28
# Peak Exp Flow at 82 is 24.57
# Peak Exp Flow at 83 is 24.57
# Peak Exp Flow at 84 is 23.04
# Peak Exp Flow at 85 is 23.04
# Peak Exp Flow at 86 is 23.07
# Peak Exp Flow at 87 is 23.07
# Peak Exp Flow at 88 is 15.81
# Peak Exp Flow at 89 is 24.54
# Peak Exp Flow at 90 is 22.98
# Peak Exp Flow at 91 is 21.99
# Peak Exp Flow at 92 is 21.15
# Peak Exp Flow at 93 is 21.15
# Peak Exp Flow at 94 is 0.0
# Peak Exp Flow at 95 is 23.31
# Peak Exp Flow at 96 is 23.31
# Peak Exp Flow at 97 is 23.79
# Peak Exp Flow at 98 is 24.24
# Peak Exp Flow at 99 is 24.24
# Peak Exp Flow at 100 is 24.78
# Peak Exp Flow at 101 is 24.78
# Peak Exp Flow at 102 is 24.51
# Peak Exp Flow at 103 is 24.51
# Peak Exp Flow at 104 is 0.21
# Peak Exp Flow at 105 is 21.96
# Peak Exp Flow at 106 is 24.03
# Peak Exp Flow at 107 is 24.03
# Peak Exp Flow at 108 is 22.26
# Peak Exp Flow at 109 is 22.26
# Peak Exp Flow at 110 is 24.27
# NOTE: For patient 5, 16 and 21, missing values have been imputated
# The imputated values are are:
# Patient 5: part 3
# Patient 16: part 4
# Patient 21: part 2
# Peak Exp Flow at 1 is 21.33
# Peak Exp Flow at 2 is 21.51
# Peak Exp Flow at 3 is 19.62
# Peak Exp Flow at 4 is 22.14
# Peak Exp Flow at 5 is 22.14
# Peak Exp Flow at 6 is 21.87
# Peak Exp Flow at 7 is 22.32
# Peak Exp Flow at 8 is 14.28
# Peak Exp Flow at 9 is 22.86
# Peak Exp Flow at 10 is 22.53
# Peak Exp Flow at 11 is 22.02
# Peak Exp Flow at 12 is 22.02
# Peak Exp Flow at 13 is 21.72
# Peak Exp Flow at 14 is 21.72
# Peak Exp Flow at 15 is 21.6
# Peak Exp Flow at 16 is 21.6
# Peak Exp Flow at 17 is 0.06
# Peak Exp Flow at 18 is 17.76
# Peak Exp Flow at 19 is 18.72
# Peak Exp Flow at 20 is 18.72
# Peak Exp Flow at 21 is 19.98
# Peak Exp Flow at 22 is 19.98
# Peak Exp Flow at 23 is 19.02
# Peak Exp Flow at 24 is 19.02
# Peak Exp Flow at 25 is 17.61
# Peak Exp Flow at 26 is 19.14
# Peak Exp Flow at 27 is 19.14
# Peak Exp Flow at 28 is 16.92
# Peak Exp Flow at 29 is 16.92
# Peak Exp Flow at 30 is 16.77
# Peak Exp Flow at 31 is 18.96
# Peak Exp Flow at 32 is 19.56
# Peak Exp Flow at 33 is 17.64
# Peak Exp Flow at 34 is 16.74
# Peak Exp Flow at 35 is 17.16
# Peak Exp Flow at 36 is 19.2
# Peak Exp Flow at 37 is 19.2
# Peak Exp Flow at 38 is 19.71
# Peak Exp Flow at 39 is 20.19
# Peak Exp Flow at 40 is 20.19
# Peak Exp Flow at 41 is 19.77
# Peak Exp Flow at 42 is 20.97
# Peak Exp Flow at 43 is 22.26
# Peak Exp Flow at 44 is 22.26
# Peak Exp Flow at 45 is -0.36
# Peak Exp Flow at 46 is 19.68
# Peak Exp Flow at 47 is 19.68
# Peak Exp Flow at 48 is -1.65
# Peak Exp Flow at 49 is 20.13
# Peak Exp Flow at 50 is 20.13
# Peak Exp Flow at 51 is 20.91
# Peak Exp Flow at 52 is 20.91
# Peak Exp Flow at 53 is 21.27
# Peak Exp Flow at 54 is 21.27
# Peak Exp Flow at 55 is -0.51
# Peak Exp Flow at 56 is 21.99
# Peak Exp Flow at 57 is 21.99
# Peak Exp Flow at 58 is 23.22
# Peak Exp Flow at 59 is 23.22
# Peak Exp Flow at 60 is 20.88
# Peak Exp Flow at 61 is 21.81
# Peak Exp Flow at 62 is 18.39
# Peak Exp Flow at 63 is -0.09
# Peak Exp Flow at 64 is 21.18
# Peak Exp Flow at 65 is 21.18
# Peak Exp Flow at 66 is 20.46
# Peak Exp Flow at 67 is 21.6
# Peak Exp Flow at 68 is 21.6
# Peak Exp Flow at 69 is 21.69
# Peak Exp Flow at 70 is 21.69
# Peak Exp Flow at 71 is 23.37
# Peak Exp Flow at 72 is 23.37
# Peak Exp Flow at 73 is 23.19
# Peak Exp Flow at 74 is 21.72
# Peak Exp Flow at 75 is 23.52
# Peak Exp Flow at 76 is 22.05
# Peak Exp Flow at 77 is 22.8
# Peak Exp Flow at 78 is 22.8
# Peak Exp Flow at 79 is 23.52
# Peak Exp Flow at 80 is 23.52
# Peak Exp Flow at 81 is 23.04
# Peak Exp Flow at 82 is 23.04
# Peak Exp Flow at 83 is 22.89
# Peak Exp Flow at 84 is 22.89
# Peak Exp Flow at 85 is 21.72
# Peak Exp Flow at 86 is 21.15
# Peak Exp Flow at 87 is 22.38
# Peak Exp Flow at 88 is 22.05
# Peak Exp Flow at 89 is 22.05
# Peak Exp Flow at 90 is 22.44
# Peak Exp Flow at 91 is 22.86
# Peak Exp Flow at 92 is 18.09
# Peak Exp Flow at 93 is 23.31
# Peak Exp Flow at 94 is 23.31
# Peak Exp Flow at 95 is 23.04
# Peak Exp Flow at 96 is 23.04
# Peak Exp Flow at 97 is 22.8
# Peak Exp Flow at 98 is 22.8
# Peak Exp Flow at 99 is -0.33
# Peak Exp Flow at 100 is 22.62
# Peak Exp Flow at 101 is 22.62
# Peak Exp Flow at 102 is 21.03
# Peak Exp Flow at 103 is 21.9
# Peak Exp Flow at 104 is 20.85
# Peak Exp Flow at 105 is 22.53
# Peak Exp Flow at 106 is 22.53
# Peak Exp Flow at 107 is -1.29
# Peak Exp Flow at 108 is 22.59
# Peak Exp Flow at 109 is 22.59
# Peak Exp Flow at 110 is 21.36
# Peak Exp Flow at 111 is 21.36
# Peak Exp Flow at 112 is -0.51
# Peak Exp Flow at 113 is 19.2
# Peak Exp Flow at 114 is 19.2
# Peak Exp Flow at 115 is -3.84
# Peak Exp Flow at 116 is -0.27
# Peak Exp Flow at 117 is 18.87
# Peak Exp Flow at 118 is 18.87
# Peak Exp Flow at 119 is 13.68
# Peak Exp Flow at 120 is -2.25
# Peak Exp Flow at 121 is 20.49
# Peak Exp Flow at 122 is 20.49
# Peak Exp Flow at 123 is 20.82
# Peak Exp Flow at 124 is 20.82
# Peak Exp Flow at 125 is 20.58
# Peak Exp Flow at 126 is 20.58
# Peak Exp Flow at 127 is 22.11
# Peak Exp Flow at 128 is 22.11
# Peak Exp Flow at 129 is -0.63
# Peak Exp Flow at 130 is 21.0
# Peak Exp Flow at 131 is 21.0
# Peak Exp Flow at 132 is -5.52
# Peak Exp Flow at 133 is -2.34
# Peak Exp Flow at 134 is -0.66
# Peak Exp Flow at 135 is 21.72
# Peak Exp Flow at 136 is 21.72
# Peak Exp Flow at 137 is -4.17
# Peak Exp Flow at 138 is 0.27
# Peak Exp Flow at 139 is 22.29
# Peak Exp Flow at 140 is 22.29
# Peak Exp Flow at 141 is -3.93
# Peak Exp Flow at 142 is -0.57
# Peak Exp Flow at 143 is 22.05
# Peak Exp Flow at 144 is 22.05
# Peak Exp Flow at 145 is -2.76
# NOTE: For patient 5, 16 and 21, missing values have been imputated
# The imputated values are are:
# Patient 5: part 3
# Patient 16: part 4
# Patient 21: part 2
# Peak Exp Flow at 1 is 16.74
# Peak Exp Flow at 2 is 16.74
# Peak Exp Flow at 3 is 18.27
# Peak Exp Flow at 4 is 18.27
# Peak Exp Flow at 5 is 19.77
# Peak Exp Flow at 6 is 19.77
# Peak Exp Flow at 7 is 20.01
# Peak Exp Flow at 8 is 20.01
# Peak Exp Flow at 9 is 20.52
# Peak Exp Flow at 10 is 20.52
# Peak Exp Flow at 11 is 22.17
# Peak Exp Flow at 12 is 22.17
# Peak Exp Flow at 13 is 22.68
# Peak Exp Flow at 14 is 22.68
# Peak Exp Flow at 15 is 20.82
# Peak Exp Flow at 16 is 20.82
# Peak Exp Flow at 17 is 20.34
# Peak Exp Flow at 18 is 20.34
# Peak Exp Flow at 19 is -0.33
# Peak Exp Flow at 20 is 22.68
# Peak Exp Flow at 21 is 22.08
# Peak Exp Flow at 22 is 22.08
# Peak Exp Flow at 23 is 21.09
# Peak Exp Flow at 24 is -0.33
# Peak Exp Flow at 25 is 22.26
# Peak Exp Flow at 26 is 22.26
# Peak Exp Flow at 27 is 17.58
# Peak Exp Flow at 28 is 16.65
# Peak Exp Flow at 29 is 17.88
# Peak Exp Flow at 30 is 18.48
# Peak Exp Flow at 31 is 18.48
# Peak Exp Flow at 32 is 18.9
# Peak Exp Flow at 33 is 18.9
# Peak Exp Flow at 34 is 18.66
# Peak Exp Flow at 35 is 19.62
# Peak Exp Flow at 36 is 20.19
# Peak Exp Flow at 37 is 18.81
# Peak Exp Flow at 38 is 19.74
# Peak Exp Flow at 39 is 19.68
# Peak Exp Flow at 40 is 20.58
# Peak Exp Flow at 41 is 20.37
# Peak Exp Flow at 42 is 18.3
# Peak Exp Flow at 43 is 19.47
# Peak Exp Flow at 44 is 19.47
# Peak Exp Flow at 45 is 17.19
# Peak Exp Flow at 46 is 17.19
# Peak Exp Flow at 47 is 18.18
# Peak Exp Flow at 48 is 18.18
# Peak Exp Flow at 49 is 20.55
# Peak Exp Flow at 50 is 20.55
# Peak Exp Flow at 51 is 20.49
# Peak Exp Flow at 52 is 20.49
# Peak Exp Flow at 53 is 20.13
# Peak Exp Flow at 54 is 20.13
# Peak Exp Flow at 55 is 20.46
# Peak Exp Flow at 56 is 19.41
# Peak Exp Flow at 57 is 21.3
# Peak Exp Flow at 58 is 21.3
# Peak Exp Flow at 59 is 13.41
# Peak Exp Flow at 60 is 22.14
# Peak Exp Flow at 61 is 21.99
# Peak Exp Flow at 62 is 20.82
# Peak Exp Flow at 63 is 20.82
# Peak Exp Flow at 64 is 19.89
# Peak Exp Flow at 65 is 19.89
# Peak Exp Flow at 66 is 19.98
# Peak Exp Flow at 67 is 19.98
# Peak Exp Flow at 68 is 20.1
# Peak Exp Flow at 69 is 20.1
# Peak Exp Flow at 70 is 20.28
# Peak Exp Flow at 71 is 20.28
# Peak Exp Flow at 72 is 21.66
# Peak Exp Flow at 73 is 21.66
# Peak Exp Flow at 74 is 20.61
# Peak Exp Flow at 75 is 20.79
# Peak Exp Flow at 76 is 20.79
# Peak Exp Flow at 77 is 18.6
# Peak Exp Flow at 78 is 18.6
# Peak Exp Flow at 79 is 22.17
# Peak Exp Flow at 80 is 22.17
# Peak Exp Flow at 81 is -0.3
# Peak Exp Flow at 82 is 21.87
# Peak Exp Flow at 83 is 21.87
# Peak Exp Flow at 84 is 19.59
# Peak Exp Flow at 85 is 19.59
# Peak Exp Flow at 86 is 18.27
# Peak Exp Flow at 87 is 18.27
# Peak Exp Flow at 88 is 17.91
# Peak Exp Flow at 89 is 19.47
# Peak Exp Flow at 90 is 19.47
# Peak Exp Flow at 91 is 20.88
# Peak Exp Flow at 92 is 20.88
# Peak Exp Flow at 93 is 20.58
# Peak Exp Flow at 94 is 20.58
# Peak Exp Flow at 95 is 19.17
# Peak Exp Flow at 96 is 19.47
# Peak Exp Flow at 97 is 21.99
# Peak Exp Flow at 98 is 19.56
# Peak Exp Flow at 99 is 19.02
# Peak Exp Flow at 100 is 20.82
# Peak Exp Flow at 101 is 20.82
# Peak Exp Flow at 102 is 20.73
# Peak Exp Flow at 103 is 20.73
# Peak Exp Flow at 104 is 19.74
# Peak Exp Flow at 105 is 19.62
# Peak Exp Flow at 106 is 22.26
# Peak Exp Flow at 107 is 22.26
# Peak Exp Flow at 108 is 21.36
# Peak Exp Flow at 109 is 21.36
# Peak Exp Flow at 110 is 18.75
# Peak Exp Flow at 111 is 18.75
# Peak Exp Flow at 112 is 0.33
# Peak Exp Flow at 113 is 21.66
# Peak Exp Flow at 114 is 21.66
# Peak Exp Flow at 115 is 20.82
# Peak Exp Flow at 116 is -0.75
# Peak Exp Flow at 117 is 20.67
# Peak Exp Flow at 118 is 20.67
# Peak Exp Flow at 119 is 19.77
# Peak Exp Flow at 120 is 19.77
# Peak Exp Flow at 121 is 18.63
# Peak Exp Flow at 122 is 18.69
# Peak Exp Flow at 123 is 18.66
# Peak Exp Flow at 124 is 18.78
# Peak Exp Flow at 125 is 16.53
# NOTE: For patient 5, 16 and 21, missing values have been imputated
# The imputated values are are:
# Patient 5: part 3
# Patient 16: part 4
# Patient 21: part 2
# Peak Exp Flow at 1 is 22.35
# Peak Exp Flow at 2 is 22.35
# Peak Exp Flow at 3 is 2.61
# Peak Exp Flow at 4 is 22.26
# Peak Exp Flow at 5 is 23.55
# Peak Exp Flow at 6 is 23.55
# Peak Exp Flow at 7 is 15.24
# Peak Exp Flow at 8 is 15.24
# Peak Exp Flow at 9 is 19.2
# Peak Exp Flow at 10 is 19.2
# Peak Exp Flow at 11 is 18.93
# Peak Exp Flow at 12 is 19.65
# Peak Exp Flow at 13 is 21.18
# Peak Exp Flow at 14 is 21.42
# Peak Exp Flow at 15 is 21.42
# Peak Exp Flow at 16 is 22.2
# Peak Exp Flow at 17 is 22.2
# Peak Exp Flow at 18 is 22.32
# Peak Exp Flow at 19 is 18.81
# Peak Exp Flow at 20 is 19.14
# Peak Exp Flow at 21 is 19.62
# Peak Exp Flow at 22 is 19.92
# Peak Exp Flow at 23 is 19.92
# Peak Exp Flow at 24 is 18.39
# Peak Exp Flow at 25 is 22.17
# Peak Exp Flow at 26 is 22.17
# Peak Exp Flow at 27 is 21.9
# Peak Exp Flow at 28 is 21.9
# Peak Exp Flow at 29 is 20.55
# Peak Exp Flow at 30 is 21.03
# Peak Exp Flow at 31 is 11.1
# Peak Exp Flow at 32 is -1.23
# Peak Exp Flow at 33 is 20.19
# Peak Exp Flow at 34 is 20.19
# Peak Exp Flow at 35 is -0.36
# Peak Exp Flow at 36 is 21.75
# Peak Exp Flow at 37 is 21.75
# Peak Exp Flow at 38 is 20.76
# Peak Exp Flow at 39 is 20.76
# Peak Exp Flow at 40 is -0.78
# Peak Exp Flow at 41 is 22.62
# Peak Exp Flow at 42 is 22.62
# Peak Exp Flow at 43 is 22.74
# Peak Exp Flow at 44 is 22.74
# Peak Exp Flow at 45 is 20.07
# Peak Exp Flow at 46 is 20.07
# Peak Exp Flow at 47 is 18.57
# Peak Exp Flow at 48 is 23.46
# Peak Exp Flow at 49 is 23.46
# Peak Exp Flow at 50 is -0.24
# Peak Exp Flow at 51 is 23.16
# Peak Exp Flow at 52 is 23.16
# Peak Exp Flow at 53 is 21.72
# Peak Exp Flow at 54 is 21.72
# Peak Exp Flow at 55 is 22.92
# Peak Exp Flow at 56 is 22.92
# Peak Exp Flow at 57 is 22.86
# Peak Exp Flow at 58 is -1.2
# Peak Exp Flow at 59 is 18.96
# Peak Exp Flow at 60 is 18.96
# Peak Exp Flow at 61 is 22.41
# Peak Exp Flow at 62 is 22.41
# Peak Exp Flow at 63 is 21.57
# Peak Exp Flow at 64 is 22.68
# Peak Exp Flow at 65 is 22.68
# Peak Exp Flow at 66 is 20.16
# Peak Exp Flow at 67 is -0.48
# Peak Exp Flow at 68 is 21.75
# Peak Exp Flow at 69 is 21.75
# Peak Exp Flow at 70 is 22.05
# Peak Exp Flow at 71 is 22.05
# Peak Exp Flow at 72 is 23.04
# Peak Exp Flow at 73 is 23.04
# Peak Exp Flow at 74 is 22.41
# Peak Exp Flow at 75 is 22.41
# Peak Exp Flow at 76 is -0.12
# Peak Exp Flow at 77 is 23.25
# Peak Exp Flow at 78 is 23.25
# Peak Exp Flow at 79 is 23.19
# Peak Exp Flow at 80 is 20.76
# Peak Exp Flow at 81 is 20.76
# Peak Exp Flow at 82 is 20.52
# Peak Exp Flow at 83 is 20.52
# Peak Exp Flow at 84 is 21.6
# Peak Exp Flow at 85 is 21.6
# Peak Exp Flow at 86 is 22.2
# Peak Exp Flow at 87 is 22.2
# Peak Exp Flow at 88 is 20.67
# Peak Exp Flow at 89 is 20.67
# Peak Exp Flow at 90 is 21.24
# Peak Exp Flow at 91 is 21.06
# Peak Exp Flow at 92 is 23.01
# Peak Exp Flow at 93 is 23.01
# Peak Exp Flow at 94 is 14.43
# Peak Exp Flow at 95 is 11.76
# Peak Exp Flow at 96 is 22.8
# Peak Exp Flow at 97 is 22.74
# Peak Exp Flow at 98 is 21.09
# Peak Exp Flow at 99 is 21.09
# Peak Exp Flow at 100 is 18.3
# Peak Exp Flow at 101 is 22.5
# Peak Exp Flow at 102 is 23.25
# Peak Exp Flow at 103 is 20.1
# Peak Exp Flow at 104 is 22.83
# Peak Exp Flow at 105 is 22.83
# Peak Exp Flow at 106 is 20.82
# Peak Exp Flow at 107 is 20.82
# Peak Exp Flow at 108 is 0.09
# Peak Exp Flow at 109 is 19.86
# Peak Exp Flow at 110 is 19.86
# Peak Exp Flow at 111 is 19.8
# C:\Users\Lasse\AppData\Local\Temp\ipykernel_21784\3216854777.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   breathD.at[breath,exp_t_const] = exp_Vt/breathD.at[breath,peak_exp_flow]

# %% [markdown]
# # Grid_Search

# %%
#Perform bucketing
esoData_bins = comp_halp.bin_divider(esoData,breathD)


hk_parts = comp_halp.grid_search_full(esoData, esoData_bins,breathD,patient,verbose=False)
# Out:
# created DF
# NOTE: For patient 5, 16 and 21, missing values have been imputated
# The imputated values are are:
# Patient 5: part 3
# Patient 16: part 4
# Patient 21: part 2
# ****CURRENT PATIENT IS: 11****
# **CURRENT PART IS: 1**
# breath 90 j = 28.312243414762097
# total loss for part 1 is: nan
# **CURRENT PART IS: 2**
# breath 90 j = 0.07915855910955259
# total loss for part 2 is: nan
# **CURRENT PART IS: 3**
# breath 90 j = 1947.146443901063
# total loss for part 3 is: nan
# **CURRENT PART IS: 4**
# breath 90 j = 0.6840735680951073
# total loss for part 4 is: nan
# **CURRENT PART IS: 5**
# breath 90 j = 0.4810750462907027
# total loss for part 5 is: nan
# **CURRENT PART IS: 6**
# breath 90 j = 47.367714240330386
# total loss for part 6 is: nan
# **CURRENT PART IS: 7**
# breath 90 j = 979.7247081005473
# total loss for part 7 is: nan
# **CURRENT PART IS: 8**
# breath 90 j = 1510.6907957830588
# total loss for part 8 is: nan

# %%
hk_parts
# Out:
# {1: {'tot_loss': nan,
#   'j_best': 5.775931520481853e-07,
#   'C_best': 181.0,
#   'b_best': 127},
#  2: {'tot_loss': nan,
#   'j_best': 2.1915486550318711e-07,
#   'C_best': 315.5,
#   'b_best': 83},
#  3: {'tot_loss': nan,
#   'j_best': 4.3945121806894394e-10,
#   'C_best': 204.0,
#   'b_best': 57},
#  4: {'tot_loss': nan,
#   'j_best': 3.751598678743121e-09,
#   'C_best': 227.0,
#   'b_best': 78},
#  5: {'tot_loss': nan,
#   'j_best': 1.1402742491656883e-07,
#   'C_best': 203.0,
#   'b_best': 92},
#  6: {'tot_loss': nan,
#   'j_best': 8.941194564349634e-11,
#   'C_best': 358.5,
#   'b_best': 6},
#  7: {'tot_loss': nan,
#   'j_best': 4.1266709975309135e-09,
#   'C_best': 199.5,
#   'b_best': 91},
#  8: {'tot_loss': nan,
#   'j_best': 2.4027481250501856e-08,
#   'C_best': 229.0,
#   'b_best': 27}}
